# %%
import pandas as pd
import os

# Paths
processed_path = r"C:\Users\ruham\Downloads\financial inclusion forecasting system\Financial-inclusion-forecasting-system-week10\data\processed"
file_name = "ethiopia_fi_unified_data_enriched.xlsx"

# Load dataset
df = pd.read_excel(os.path.join(processed_path, file_name))

# Quick overview
print(df.shape)
print(df.columns)
df.head()
# Out:
# (131, 34)
# Index(['record_id', 'record_type', 'category', 'pillar', 'indicator',
#        'indicator_code', 'indicator_direction', 'value_numeric', 'value_text',
#        'value_type', 'unit', 'observation_date', 'period_start', 'period_end',
#        'fiscal_year', 'gender', 'location', 'region', 'source_name',
#        'source_type', 'source_url', 'confidence', 'related_indicator',
#        'relationship_type', 'impact_direction', 'impact_magnitude',
#        'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country',
#        'collected_by', 'collection_date', 'original_text', 'notes'],
#       dtype='object')
#    record_id  record_type category  pillar               indicator  \
# 0          0  observation      NaN  ACCESS  Account Ownership Rate
# 1          0  observation      NaN  ACCESS  Account Ownership Rate
# 2          0  observation      NaN  ACCESS  Account Ownership Rate
# 3          0  observation      NaN  ACCESS  Account Ownership Rate
# 4          0  observation      NaN  ACCESS  Account Ownership Rate
#
#   indicator_code indicator_direction  value_numeric value_text  value_type  \
# 0  ACC_OWNERSHIP       higher_better           22.0        NaN  percentage
# 1  ACC_OWNERSHIP       higher_better           35.0        NaN  percentage
# 2  ACC_OWNERSHIP       higher_better           46.0        NaN  percentage
# 3  ACC_OWNERSHIP       higher_better           56.0        NaN  percentage
# 4  ACC_OWNERSHIP       higher_better           36.0        NaN  percentage
#
#    ... impact_direction impact_magnitude impact_estimate lag_months  \
# 0  ...              NaN              NaN             NaN        NaN
# 1  ...              NaN              NaN             NaN        NaN
# 2  ...              NaN              NaN             NaN        NaN
# 3  ...              NaN              NaN             NaN        NaN
# 4  ...              NaN              NaN             NaN        NaN
#
#   evidence_basis comparable_country collected_by  collection_date  \
# 0            NaN    Example_Trainee   2025-01-20              NaN
# 1            NaN    Example_Trainee   2025-01-20              NaN
# 2            NaN    Example_Trainee   2025-01-20              NaN
# 3            NaN    Example_Trainee   2025-01-20              NaN
# 4            NaN    Example_Trainee   2025-01-20              NaN
#
#           original_text notes
# 0         Baseline year   NaN
# 1                   NaN   NaN
# 2                   NaN   NaN
# 3  Gender disaggregated   NaN
# 4  Gender disaggregated   NaN
#
# [5 rows x 34 columns]

# %%
# Info & types
df.info()

# Missing values
print(df.isna().sum())

# Quick statistics
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            131 non-null    int64
#  1   record_type          131 non-null    object
#  2   category             10 non-null     object
#  3   pillar               33 non-null     object
#  4   indicator            43 non-null     object
#  5   indicator_code       43 non-null     object
#  6   indicator_direction  33 non-null     object
#  7   value_numeric        33 non-null     float64
#  8   value_text           10 non-null     object
#  9   value_type           43 non-null     object
#  10  unit                 33 non-null     object
#  11  observation_date     43 non-null     datetime64[ns]
#  12  period_start         10 non-null     datetime64[ns]
#  13  period_end           10 non-null     datetime64[ns]
#  14  fiscal_year          43 non-null     object
#  15  gender               43 non-null     object
#  16  location             43 non-null     object
#  17  region               0 non-null      float64
#  18  source_name          43 non-null     object
#  19  source_type          131 non-null    object
#  20  source_url           31 non-null     object
#  21  confidence           43 non-null     object
#  22  related_indicator    0 non-null      float64
#  23  relationship_type    0 non-null      float64
#  24  impact_direction     0 non-null      float64
#  25  impact_magnitude     0 non-null      float64
#  26  impact_estimate      0 non-null      float64
#  27  lag_months           0 non-null      float64
#  28  evidence_basis       0 non-null      float64
#  29  comparable_country   43 non-null     object
#  30  collected_by         43 non-null     datetime64[ns]
#  31  collection_date      10 non-null     object
#  32  original_text        33 non-null     object
#  33  notes                0 non-null      float64
# dtypes: datetime64[ns](4), float64(10), int64(1), object(19)
# memory usage: 34.9+ KB
# record_id                0
# record_type              0
# category               121
# pillar                  98
# indicator               88
# indicator_code          88
# indicator_direction     98
# value_numeric           98
# value_text             121
# value_type              88
# unit                    98
# observation_date        88
# period_start           121
# period_end             121
# fiscal_year             88
# gender                  88
# location                88
# region                 131
# source_name             88
# source_type              0
# source_url             100
# confidence              88
# related_indicator      131
# relationship_type      131
# impact_direction       131
# impact_magnitude       131
# impact_estimate        131
# lag_months             131
# evidence_basis         131
# comparable_country      88
# collected_by            88
# collection_date        121
# original_text           98
# notes                  131
# dtype: int64
#          record_id record_type        category  pillar  \
# count   131.000000         131              10      33
# unique         NaN           4               7       4
# top            NaN       event  product_launch  ACCESS
# freq           NaN          63               2      16
# mean     29.893130         NaN             NaN     NaN
# min       0.000000         NaN             NaN     NaN
# 25%       0.000000         NaN             NaN     NaN
# 50%      23.000000         NaN             NaN     NaN
# 75%      55.500000         NaN             NaN     NaN
# max      88.000000         NaN             NaN     NaN
# std      29.610614         NaN             NaN     NaN
#
#                      indicator indicator_code indicator_direction  \
# count                       43             43                  33
# unique                      29             29                   3
# top     Account Ownership Rate  ACC_OWNERSHIP       higher_better
# freq                         7              7                  27
# mean                       NaN            NaN                 NaN
# min                        NaN            NaN                 NaN
# 25%                        NaN            NaN                 NaN
# 50%                        NaN            NaN                 NaN
# 75%                        NaN            NaN                 NaN
# max                        NaN            NaN                 NaN
# std                        NaN            NaN                 NaN
#
#         value_numeric value_text  value_type  ... impact_direction  \
# count    3.300000e+01         10          43  ...              0.0
# unique            NaN          3           6  ...              NaN
# top               NaN   Launched  percentage  ...              NaN
# freq              NaN          7          17  ...              NaN
# mean     9.437258e+10        NaN         NaN  ...              NaN
# min      1.080000e+00        NaN         NaN  ...              NaN
# 25%      2.400000e+01        NaN         NaN  ...              NaN
# 50%      6.140000e+01        NaN         NaN  ...              NaN
# 75%      1.500000e+07        NaN         NaN  ...              NaN
# max      2.380000e+12        NaN         NaN  ...              NaN
# std      4.231061e+11        NaN         NaN  ...              NaN
#
#        impact_magnitude impact_estimate lag_months  evidence_basis  \
# count               0.0             0.0        0.0             0.0
# unique              NaN             NaN        NaN             NaN
# top                 NaN             NaN        NaN             NaN
# freq                NaN             NaN        NaN             NaN
# mean                NaN             NaN        NaN             NaN
# min                 NaN             NaN        NaN             NaN
# 25%                 NaN             NaN        NaN             NaN
# 50%                 NaN             NaN        NaN             NaN
# 75%                 NaN             NaN        NaN             NaN
# max                 NaN             NaN        NaN             NaN
# std                 NaN             NaN        NaN             NaN
#
#        comparable_country         collected_by  \
# count                  43                   43
# unique                  1                  NaN
# top       Example_Trainee                  NaN
# freq                   43                  NaN
# mean                  NaN  2025-01-20 00:00:00
# min                   NaN  2025-01-20 00:00:00
# 25%                   NaN  2025-01-20 00:00:00
# 50%                   NaN  2025-01-20 00:00:00
# 75%                   NaN  2025-01-20 00:00:00
# max                   NaN  2025-01-20 00:00:00
# std                   NaN                  NaN
#
#                                     collection_date         original_text  \
# count                                            10                    33
# unique                                           10                    32
# top     Account ownership increased from 46% to 49%  Gender disaggregated
# freq                                              1                     2
# mean                                            NaN                   NaN
# min                                             NaN                   NaN
# 25%                                             NaN                   NaN
# 50%                                             NaN                   NaN
# 75%                                             NaN                   NaN
# max                                             NaN                   NaN
# std                                             NaN                   NaN
#
#        notes
# count    0.0
# unique   NaN
# top      NaN
# freq     NaN
# mean     NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# std      NaN
#
# [11 rows x 34 columns]

# %%
# Year and month from observation_date
df['year'] = df['observation_date'].dt.year
df['month'] = df['observation_date'].dt.month
df['quarter'] = df['observation_date'].dt.quarter

# %%
# normalize value_numeric by pillar
df['value_norm'] = df.groupby('pillar')['value_numeric'].transform(lambda x: (x - x.mean()) / x.std())

# %%
# Convert record_type and source_type to category
df['record_type'] = df['record_type'].astype('category')
df['source_type'] = df['source_type'].astype('category')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Observations per year
sns.countplot(x='year', data=df)
plt.title('Observations per Year')
plt.show()

# Observations per pillar
sns.countplot(x='pillar', data=df)
plt.title('Observations per Pillar')
plt.show()

# %%
# Numeric correlations
corr = df[['value_numeric', 'value_norm']].corr()
print(corr)

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
#                value_numeric  value_norm
# value_numeric       1.000000    0.556754
# value_norm          0.556754    1.000000

# %%
sns.heatmap(df.isna(), cbar=False)
plt.title('Missing Values Heatmap')
plt.show()

# %%
output_file = os.path.join(processed_path, "ethiopia_fi_features.xlsx")
df.to_excel(output_file, index=False)
print(f"Processed features saved to: {output_file}")
# Out:
# Processed features saved to: C:\Users\ruham\Downloads\financial inclusion forecasting system\Financial-inclusion-forecasting-system-week10\data\processed\ethiopia_fi_features.xlsx
